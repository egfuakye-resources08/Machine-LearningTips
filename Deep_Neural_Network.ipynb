# %% [markdown]
# <a href="https://colab.research.google.com/github/egfuakye-resources08/Machine-LearningTips/blob/main/Deep_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![DeepN (1).png](data:image/png;base64,...)

# %% [markdown]
# **Deep Neural Networks Tutorials from the Self Driving Class in Udemy**

# %%
import numpy as np 
import keras
from sklearn import datasets
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from numpy.core.function_base import linspace
from numpy.core.function_base import linspace
import matplotlib.pyplot as plt

# %%
np.random.seed(0)

# %%
n_pts = 500
X, y = datasets.make_circles(n_samples=n_pts, random_state=123, noise=0.1)
print(X)
print(y)

# %%
plt.scatter(X[y==0, 0], X[y==0, 1])#y==sets the boolean flag
plt.scatter(X[y==1, 0], X[y==1, 1])

# %%
model = Sequential() #Deep learning networks make use of hidden layers
model.add(Dense(4, input_shape=(2,), activation='sigmoid' ))
model.add(Dense(1, activation='sigmoid'))
model.compile(Adam(learning_rate = 0.01), 'binary_crossentropy', metrics=['accuracy'])

# %%
h = model.fit(x=X, y=y, verbose = 1, batch_size = 20, epochs=100, shuffle='true')
# Out:
# Epoch 1/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6657 - accuracy: 0.5880
# Epoch 2/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6653 - accuracy: 0.5780
# Epoch 3/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6650 - accuracy: 0.5860
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6650 - accuracy: 0.5760
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6669 - accuracy: 0.6040
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6666 - accuracy: 0.5680
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6652 - accuracy: 0.5780
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6640 - accuracy: 0.5940
# Epoch 9/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6642 - accuracy: 0.5740
# Epoch 10/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6633 - accuracy: 0.5800
# Epoch 11/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6625 - accuracy: 0.5800
# Epoch 12/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6631 - accuracy: 0.5820
# Epoch 13/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6629 - accuracy: 0.5820
# Epoch 14/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6618 - accuracy: 0.5860
# Epoch 15/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6615 - accuracy: 0.5800
# Epoch 16/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6619 - accuracy: 0.5820
# Epoch 17/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6616 - accuracy: 0.5820
# Epoch 18/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6618 - accuracy: 0.5760
# Epoch 19/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6603 - accuracy: 0.5800
# Epoch 20/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6603 - accuracy: 0.5980
# Epoch 21/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6594 - accuracy: 0.5940
# Epoch 22/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6592 - accuracy: 0.5820
# Epoch 23/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6587 - accuracy: 0.5880
# Epoch 24/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6584 - accuracy: 0.5880
# Epoch 25/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6582 - accuracy: 0.6020
# Epoch 26/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6566 - accuracy: 0.5840
# Epoch 27/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6562 - accuracy: 0.5900
# Epoch 28/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6554 - accuracy: 0.5800
# Epoch 29/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6547 - accuracy: 0.5860
# Epoch 30/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6545 - accuracy: 0.5960
# Epoch 31/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6515 - accuracy: 0.6060
# Epoch 32/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6503 - accuracy: 0.6120
# Epoch 33/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6488 - accuracy: 0.6000
# Epoch 34/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6468 - accuracy: 0.6000
# Epoch 35/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6451 - accuracy: 0.6120
# Epoch 36/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6438 - accuracy: 0.6100
# Epoch 37/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6417 - accuracy: 0.6140
# Epoch 38/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6389 - accuracy: 0.6320
# Epoch 39/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6369 - accuracy: 0.6460
# Epoch 40/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6353 - accuracy: 0.6540
# Epoch 41/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6369 - accuracy: 0.6440
# Epoch 42/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6344 - accuracy: 0.6540
# Epoch 43/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6295 - accuracy: 0.6780
# Epoch 44/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6260 - accuracy: 0.6800
# Epoch 45/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6237 - accuracy: 0.6960
# Epoch 46/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6222 - accuracy: 0.6920
# Epoch 47/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6185 - accuracy: 0.6980
# Epoch 48/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6160 - accuracy: 0.7080
# Epoch 49/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6159 - accuracy: 0.7200
# Epoch 50/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6108 - accuracy: 0.7180
# Epoch 51/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6099 - accuracy: 0.7180
# Epoch 52/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6084 - accuracy: 0.7320
# Epoch 53/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6049 - accuracy: 0.7380
# Epoch 54/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6026 - accuracy: 0.7500
# Epoch 55/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5988 - accuracy: 0.7620
# Epoch 56/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5979 - accuracy: 0.7540
# Epoch 57/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5948 - accuracy: 0.7760
# Epoch 58/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5921 - accuracy: 0.7920
# Epoch 59/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5907 - accuracy: 0.8020
# Epoch 60/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5878 - accuracy: 0.7940
# Epoch 61/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5858 - accuracy: 0.7940
# Epoch 62/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5836 - accuracy: 0.8080
# Epoch 63/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5810 - accuracy: 0.8160
# Epoch 64/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5804 - accuracy: 0.8060
# Epoch 65/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5775 - accuracy: 0.8000
# Epoch 66/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5753 - accuracy: 0.8140
# Epoch 67/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5726 - accuracy: 0.8080
# Epoch 68/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5698 - accuracy: 0.8040
# Epoch 69/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5685 - accuracy: 0.7940
# Epoch 70/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5660 - accuracy: 0.7900
# Epoch 71/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5635 - accuracy: 0.7940
# Epoch 72/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5600 - accuracy: 0.8060
# Epoch 73/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5585 - accuracy: 0.7920
# Epoch 74/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5564 - accuracy: 0.7760
# Epoch 75/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5545 - accuracy: 0.7820
# Epoch 76/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5515 - accuracy: 0.7860
# Epoch 77/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5503 - accuracy: 0.7780
# Epoch 78/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5477 - accuracy: 0.8000
# Epoch 79/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5455 - accuracy: 0.7800
# Epoch 80/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5439 - accuracy: 0.7680
# Epoch 81/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5426 - accuracy: 0.7720
# Epoch 82/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5408 - accuracy: 0.7820
# Epoch 83/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5376 - accuracy: 0.7800
# Epoch 84/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5364 - accuracy: 0.7740
# Epoch 85/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5343 - accuracy: 0.7740
# Epoch 86/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5361 - accuracy: 0.7660
# Epoch 87/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5345 - accuracy: 0.7640
# Epoch 88/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5315 - accuracy: 0.7780
# Epoch 89/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5286 - accuracy: 0.7740
# Epoch 90/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5275 - accuracy: 0.7660
# Epoch 91/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5257 - accuracy: 0.7680
# Epoch 92/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5246 - accuracy: 0.7680
# Epoch 93/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5240 - accuracy: 0.7660
# Epoch 94/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5223 - accuracy: 0.7700
# Epoch 95/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5204 - accuracy: 0.7740
# Epoch 96/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5194 - accuracy: 0.7720
# Epoch 97/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5196 - accuracy: 0.7760
# Epoch 98/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5191 - accuracy: 0.7800
# Epoch 99/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5155 - accuracy: 0.7720
# Epoch 100/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5147 - accuracy: 0.7700

# %%
plt.plot(h.history['accuracy'])
plt.xlabel('epoch')
plt.legend(['accuracy'])
plt.title('accuracy')
# Out:
# Text(0.5, 1.0, 'accuracy')

# %%
plt.plot(h.history['loss'])
plt.xlabel('epoch')
plt.legend(['loss'])
plt.title('loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %%
def plot_decision_boundary(X, y, model):
    x_span = np.linspace(min(X[:, 0]) - 0.25, max(X[:, 0]) + 0.25)
    y_span = np.linspace(min(X[:, 0]) - 0.25, max(X[:, 0]) + 0.25)
    xx, yy = np.meshgrid(x_span, y_span)
    xx_, yy_, = xx.ravel(), yy.ravel()
    grid = np.c_[xx_, yy_]
    pred_func = model.predict(grid)
    z =  pred_func.reshape(xx.shape)
    plt.contourf(xx, yy, z)

# %%
plot_decision_boundary(X, y, model)
plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])

# %%
plot_decision_boundary(X, y, model)
plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])
x = 0.1
y = 0.75
point = np.array([[x, y]])
prediction = model.predict(point)
plt.plot([x], [y], marker="o", markersize=30, color="red")
print("Prediction is:", prediction)
# Out:
# Prediction is: [[0.8171248]]
